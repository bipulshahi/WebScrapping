# %%
#web scraping ----extracting data from web
#Beautiful soup

# %%
from urllib.request import urlopen #open urls

# %%
#urlopen----function ----allows to open url and allows
# to retrieve html content of web page

# %%
from bs4 import BeautifulSoup
#data ----html/xml

# %%
url="http://www.hubertiming.com/results/2017GPTR10K"

# %%
html=urlopen(url)

# %%
soup=BeautifulSoup(html,'lxml')

# %%
#title
t=soup.title

# %%
print(t)
# Out:
# <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>

# %%
text=soup.get_text()
print(text)
# Out:
# Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2017 Intel Great Place to Run 10K \ Urban Clash Games
#  Hillsboro Stadium, Hillsboro, OR
#  June 2nd, 2017
#
#
#
#
#
#
#
#
#  Email
#                         timing@hubertiming.com with results questions. Please include your bib number if you have it.
#
#
#
#
#
#
#
#
#
# Huber Timing Home
#
#
#
#
#
# 10K:
#
#
# Finishers:
# 577
#
#
# Male:
# 414
#
#
# Female:
# 163
#
#
#
#
#
#
#
#
#
#  5K Individual
#  5K Team
#  10K Individual
#  10K Team
#  Summary
#
#
#
#
# Indvidual Results
#
#
#
# 10K Results
#
#
#
# Search:
#
# Search
# Division:
#
# Men
# Women
# Non-Binary
# Masters Men
# Masters Women
# Masters Non-Binary
#
# F 18-25
# F 26-35
# F 36-45
# F 46-55
# F Under 18
# M 18-25
# M 26-35
# M 36-45
# M 46-55
# M 55+
# M Under 18
#  Team:
#
# Unattached
# COLUMBIA TEAM A
# COLUMBIA TEAM B
# COLUMBIA TEAM C
# COLUMBIA TEAM D
# COLUMBIA TEAM E
# DTNA1
# DTNA2
# DTNA3
# ...

# %%
#find_all
#<a>------ hyperlinks
#<table>----table
#<th> ---table header
#<tr> ---table rows
#<td> ----table cells
soup.find_all('a')
# Out:
# [<a href="mailto:timing@hubertiming.com">timing@hubertiming.com</a>,
#  <a href="https://www.hubertiming.com">Huber Timing Home</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> 5K Individual</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 5K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 10K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/summary/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i class="fa fa-stream"></i> Summary</a>,
#  <a id="individual" name="individual"></a>,
#  <a data-url="/results/2017GPTR10K" href="#tabs-1" id="rootTab" style="font-size: 18px">10K Results</a>,
# ...

# %%
links=soup.find_all('a')
for l in links:
    print(l.get("href"))
# Out:
# mailto:timing@hubertiming.com
# https://www.hubertiming.com
# /results/2017GPTR
# /results/team/2017GPTR
# /results/team/2017GPTR10K
# /results/summary/2017GPTR10K
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/
# None

# %%
#extract first 10 rows
rows=soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr colspan="2">
# <b>10K:</b>
# </tr>, <tr>
# <td>Finishers:</td>
# <td>577</td>
# </tr>, <tr>
# <td>Male:</td>
# <td>414</td>
# </tr>, <tr>
# <td>Female:</td>
# <td>163</td>
# </tr>, <tr class="header">
# <th>Place</th>
# <th>Bib</th>
# <th>Name</th>
# <th>Gender</th>
# <th>City</th>
# <th>State</th>
# <th>Time</th>
# <th>Gun Time</th>
# <th>Team</th>
# </tr>, <tr data-bib="814">
# <td>1</td>
# <td>814</td>
# <td>
#
#                     JARED WILSON
#
#                 </td>
# <td>M</td>
# <td>TIGARD</td>
# <td>OR</td>
# <td>36:21</td>
# <td>36:24</td>
# <td></td>
# </tr>, <tr data-bib="573">
# <td>2</td>
# <td>573</td>
# <td>
#
#                     NATHAN A SUSTERSIC
#
#                 </td>
# <td>M</td>
# <td>PORTLAND</td>
# <td>OR</td>
# <td>36:42</td>
# <td>36:45</td>
# <td>
# <img class="lazy teamThumbs" data-src="/teamLogoThumbnail/logo?teamName=INTEL%20TEAM%20F&amp;raceId=1251&amp;state=OR"/>
#                             INTEL TEAM F
#                         </td>
# ...

# %%
for r in rows:
    table_cell=soup.find_all('td')
print(table_cell)
# Out:
# [<td>Finishers:</td>, <td>577</td>, <td>Male:</td>, <td>414</td>, <td>Female:</td>, <td>163</td>, <td>1</td>, <td>814</td>, <td>
#
#                     JARED WILSON
#
#                 </td>, <td>M</td>, <td>TIGARD</td>, <td>OR</td>, <td>36:21</td>, <td>36:24</td>, <td></td>, <td>2</td>, <td>573</td>, <td>
#
#                     NATHAN A SUSTERSIC
#
#                 </td>, <td>M</td>, <td>PORTLAND</td>, <td>OR</td>, <td>36:42</td>, <td>36:45</td>, <td>
# <img class="lazy teamThumbs" data-src="/teamLogoThumbnail/logo?teamName=INTEL%20TEAM%20F&amp;raceId=1251&amp;state=OR"/>
#                             INTEL TEAM F
#                         </td>, <td>3</td>, <td>687</td>, <td>
#
#                     FRANCISCO MAYA
#
#                 </td>, <td>M</td>, <td>PORTLAND</td>, <td>OR</td>, <td>37:44</td>, <td>37:48</td>, <td></td>, <td>4</td>, <td>623</td>, <td>
#
#                     PAUL MORROW
#
# ...

# %%
type(table_cell)
# Out:
# bs4.element.ResultSet

# %%
str_table_cell=str(table_cell)

# %%
text_data=BeautifulSoup(str_table_cell,'lxml').get_text()

# %%
print(text_data)
# Out:
# [Finishers:, 577, Male:, 414, Female:, 163, 1, 814,
#
#                     JARED WILSON
#
#                 , M, TIGARD, OR, 36:21, 36:24, , 2, 573,
#
#                     NATHAN A SUSTERSIC
#
#                 , M, PORTLAND, OR, 36:42, 36:45,
#
#                             INTEL TEAM F
#                         , 3, 687,
#
#                     FRANCISCO MAYA
#
#                 , M, PORTLAND, OR, 37:44, 37:48, , 4, 623,
#
#                     PAUL MORROW
#
#                 , M, BEAVERTON, OR, 38:34, 38:37, , 5, 569,
#
#                     DEREK G OSBORNE
#
#                 , M, HILLSBORO, OR, 39:21, 39:24,
#
#                             INTEL TEAM F
#                         , 6, 642,
#
#                     JONATHON TRAN
#
#                 , M, PORTLAND, OR, 39:49, 39:55, , 7, 144,
#
#                     GEORGE TOTONCHY
#
#                 , M, PORTLAND, OR, 40:04, 40:17, , 8, 395,
#
#                     BENJAMIN C CHAFFIN
#
# ...

# %%
def get_html_content(link):
    html=urlopen(link)
    soup=BeautifulSoup(html,'html.parser')
    return soup

# %%
content=get_html_content("https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population")

# %%
tables=contents.find_all('table')

# %%
for t in tables:
    print(t.prettify())
# Out:
# <table class="wikitable sortable" style="text-align:right">
#  <tbody>
#   <tr class="is-sticky">
#    <th>
#    </th>
#    <th style="width:17em">
#     <a href="/wiki/List_of_sovereign_states" title="List of sovereign states">
#      Country
#     </a>
#     /
#     <a href="/wiki/Dependent_territory" title="Dependent territory">
#      Dependency
#     </a>
#    </th>
#    <th>
#     Population
#    </th>
#    <th style="width:2em">
#     % of
#     <br/>
#     world
#    </th>
#    <th>
#     Date
#    </th>
#    <th>
#     <span class="nowrap">
#      Source (official or from
#     </span>
#     <br/>
#     the
#     <a href="/wiki/United_Nations" title="United Nations">
#      United Nations
#     </a>
#     )
#    </th>
#    <th class="unsortable">
#    </th>
#   </tr>
#   <tr>
#    <th>
#     –
#    </th>
#    <td style="text-align:left">
#     <b>
#      World
#     </b>
#    </td>
#    <td>
#     <b>
#      8,073,638,000
#     </b>
#    </td>
#    <td>
#     <b>
# ...

# %%
# The cell with the country name for each row includes a link to the country webpage on Wikipedia
table = content.find('table', {'class': 'wikitable sortable'})
rows = table.find_all('tr')

# List of all links
for row in rows:
    # print(row)
    cells = row.find_all('td')
    
    if len(cells) > 1:
        try:
            
            country_link = cells[0].find('a')
            if country_link.get('href').find('Demographics'):
                print(country_link.get('href')[22:])
                a = 0
        except:
            pass
# Out:
# lic_of_the_Congo
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ic
#
#
#
#
#
#
#
#
# ates
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Congo
#
#
# Republic
#
#
#
# ne
#
# and
#
#
#
#
#
#
#
#
#
# )
#
#
# govina
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# a
#
# ago
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A9_and_Pr%C3%ADncipe
#
#
#
#
# akh
#
#
# d_the_Grenadines
#
# _of_Micronesia
#
# uda
#
#
# rgin_Islands
#
#
#
#
#
#
#
#
#
#
# _Islands
# Nevis
# _Islands
#
#
#
#
#
#
# Saint_Martin
# slands
#
#
#
#
#
# a
#
# 9lemy
# _Miquelon
# cension_and_Tristan_da_Cunha
#
#
#
#
#
#
#
# Islands

# %%
def getAdditionalDetails(url):
    try:
        country_page = getHTMLContent('https://en.wikipedia.org/wiki/' + url)
        # print(country_page)
        table = country_page.find('table', {'class': 'infobox ib-country vcard'})
        additional_details = []
        read_content = False
        for tr in table.find_all('tr'):
            if (tr.get('class') == ['mergedtoprow'] and not read_content):
                link = tr.find('a')
                if (link and (link.get_text().strip() == 'Area' or
                   (link.get_text().strip() == 'GDP' and tr.find('span').get_text().strip() == '(nominal)'))):
                    read_content = True
            elif ((tr.get('class') == ['mergedrow'] or tr.get('class') == ['mergedbottomrow']) and read_content):
                additional_details.append(tr.find('td').get_text().strip('\n')) 
                if (tr.find('div').get_text().strip() != '•\xa0Total area' and
                   tr.find('div').get_text().strip() != '•\xa0Total'):
                    read_content = False
                    print("IF:",tr.find('div').get_text().strip())
                else:
                    print("ELSE:",tr.find('div').get_text().strip(),read_content)
        return additional_details
    except Exception as error:
        print('Error occured: {}'.format(error))
        return []

# %%
d
# Out:
# Empty DataFrame
# Columns: []
# Index: []
